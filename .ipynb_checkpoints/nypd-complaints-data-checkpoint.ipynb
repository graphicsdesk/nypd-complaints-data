# %% [markdown]
# # NYPD Complaints Data on Manhattan CD9, Manhattan, and Bronx CD !!
#
# The first section covers data regarding the number of complaints made in the aforementioned regions across the last decade (2010-2019).
#
# The second section covers complaints and arrests made in the 4 weeks before and after a major event (an event that sparked much unrest/protest) regarding police brutality.
#
# #### Events mentioned:
# - The start of national coverage (and protest) of the Trayvon Martin Shooting
# - The acquittal of George Zimmerman
# - The Grand Jury's decision to not indict Michael Brown's shooter
# - The death of Freddie Gray
# - The death of George Floyd

# %% [markdown]
# # Complaint Data across the last decade (2010-2019)

# %% [markdown]
# ## Manhattan

# %%
display(manhattanYears)
# Out:
#                Total Complaints  Complaints w/ Black Suspects  \
# 2010                      30135                         14548
# 2011                      29196                         14185
# 2012                      30898                         15116
# 2013                      30924                         15285
# 2014                      36805                         18094
# 2015                      56495                         27803
# 2016                      59993                         29380
# 2017                      63165                         31354
# 2018                      64160                         31926
# 2019                      69868                         35754
# Total/Average            471639                        233445
#
#                Percentage of Black-Suspect Complaints  \
# 2010                                        48.276091
# 2011                                        48.585423
# 2012                                        48.922260
# ...

# %% [markdown]
# ## Manhattan CD 9

# %%
display(cd9Years)
# Out:
#                Total Complaints  Complaints w/ Black Suspects  \
# 2010                       2399                          1399
# 2011                       2363                          1329
# 2012                       2455                          1364
# 2013                       2376                          1285
# 2014                       2831                          1553
# 2015                       4101                          2219
# 2016                       3981                          2145
# 2017                       3514                          1905
# 2018                       3838                          2183
# 2019                       4256                          2480
# Total/Average             32114                         17862
#
#                Percentage of Black-Suspect Complaints  \
# 2010                                        58.315965
# 2011                                        56.242065
# 2012                                        55.560081
# ...

# %% [markdown]
# ## Bronx CD 11

# %%
display(cd11Years)
# Out:
#                Total Complaints  Complaints w/ Black Suspects  \
# 2010                       2347                           966
# 2011                       2242                           916
# 2012                       1971                           853
# 2013                       1905                           825
# 2014                       2445                          1043
# 2015                       3716                          1580
# 2016                       4016                          1717
# 2017                       4178                          1822
# 2018                       4077                          1713
# 2019                       3648                          1604
# Total/Average             30545                         13039
#
#                Percentage of Black-Suspect Complaints  \
# 2010                                        41.158926
# 2011                                        40.856378
# 2012                                        43.277524
# ...

# %% [markdown]
# # Complaint Data before/after specific events

# %% [markdown]
# ## Trayvon Martin's Death (2012)

# %% [markdown]
# ### Manhattan CD9

# %%
display(martinDFcd9)
# Out:
#           Complaints w/ Black Suspects  Total Complaints  \
# 2/13-19                             27                47
# 2/20-26                             17                48
# 2/27-3/4                            28                42
# 3/5-11                              25                47
# 3/12-18                             27                43
# 3/19-25                             21                41
# 3/26-4/1                            24                43
# 4/2-4/8                             24                44
#
#           Percentage of Black-Suspect Complaints  \
# 2/13-19                                57.446809
# 2/20-26                                35.416667
# 2/27-3/4                               66.666667
# 3/5-11                                 53.191489
# 3/12-18                                62.790698
# 3/19-25                                51.219512
# 3/26-4/1                               55.813953
# 4/2-4/8                                54.545455
#
# ...

# %% [markdown]
# ### Manhattan

# %%
display(martinDFm)
# Out:
#           Complaints w/ Black Suspects  Total Complaints  \
# 2/13-19                            258               574
# 2/20-26                            215               535
# 2/27-3/4                           313               583
# 3/5-11                             259               544
# 3/12-18                            301               634
# 3/19-25                            310               637
# 3/26-4/1                           316               609
# 4/2-4/8                            281               584
#
#           Percentage of Black-Suspect Complaints  \
# 2/13-19                                44.947735
# 2/20-26                                40.186916
# 2/27-3/4                               53.687822
# 3/5-11                                 47.610294
# 3/12-18                                47.476341
# 3/19-25                                48.665620
# 3/26-4/1                               51.888342
# 4/2-4/8                                48.116438
#
# ...

# %% [markdown]
# ## Acquittal of George Zimmerman (2013)

# %% [markdown]
# ### Manhattan CD9

# %%
display(zimmermanDFcd9)
# Out:
#           Complaints w/ Black Suspects  Total Complaints  \
# 6/16-22                             36                61
# 6/23-29                             27                47
# 6/30-7/6                            27                56
# 7/7-13                              31                57
# 7/14-20                             25                45
# 7/21-27                             31                53
# 7/28-8/3                            33                56
# 8/4-10                              25                41
#
#           Percentage of Black-Suspect Complaints  \
# 6/16-22                                59.016393
# 6/23-29                                57.446809
# 6/30-7/6                               48.214286
# 7/7-13                                 54.385965
# 7/14-20                                55.555556
# 7/21-27                                58.490566
# 7/28-8/3                               58.928571
# 8/4-10                                 60.975610
#
# ...

# %% [markdown]
# ### Manhattan

# %%
display(zimmermanDFm)
# Out:
#           Complaints w/ Black Suspects  Total Complaints  \
# 6/16-22                            337               691
# 6/23-29                            343               654
# 6/30-7/6                           257               568
# 7/7-13                             345               657
# 7/14-20                            353               668
# 7/21-27                            344               696
# 7/28-8/3                           334               647
# 8/4-10                             322               636
#
#           Percentage of Black-Suspect Complaints  \
# 6/16-22                                48.769899
# 6/23-29                                52.446483
# 6/30-7/6                               45.246479
# 7/7-13                                 52.511416
# 7/14-20                                52.844311
# 7/21-27                                49.425287
# 7/28-8/3                               51.622875
# 8/4-10                                 50.628931
#
# ...

# %% [markdown]
# ## Ferguson Grand Jury (No Indictment) (2014)

# %% [markdown]
# ### Manhattan CD9

# %%
display(fergusonDFcd9)
# Out:
#             Complaints w/ Black Suspects  Total Complaints  \
# 10/28-11/3                            48                85
# 11/4-10                               39                93
# 11/11-17                              57                98
# 11/18-24                              33                76
# 11/25-12/1                            36                76
# 12/2-8                                31                71
# 12/9-15                               36                74
# 12/16-22                              39                64
#
#             Percentage of Black-Suspect Complaints  \
# 10/28-11/3                               56.470588
# 11/4-10                                  41.935484
# 11/11-17                                 58.163265
# 11/18-24                                 43.421053
# 11/25-12/1                               47.368421
# 12/2-8                                   43.661972
# 12/9-15                                  48.648649
# ...

# %% [markdown]
# ### Manhattan

# %%
display(fergusonDFm)
# Out:
#             Complaints w/ Black Suspects  Total Complaints  \
# 10/28-11/3                           495              1067
# 11/4-10                              507              1136
# 11/11-17                             510              1037
# 11/18-24                             501              1044
# 11/25-12/1                           444               893
# 12/2-8                               405               921
# 12/9-15                              452               969
# 12/16-22                             449               914
#
#             Percentage of Black-Suspect Complaints  \
# 10/28-11/3                               46.391753
# 11/4-10                                  44.630282
# 11/11-17                                 49.180328
# 11/18-24                                 47.988506
# 11/25-12/1                               49.720045
# 12/2-8                                   43.973941
# 12/9-15                                  46.646027
# ...

# %% [markdown]
# ## Death of Freddie Gray (2015)

# %% [markdown]
# ### Manhattan CD9

# %%
display(grayDFcd9)
# Out:
#           Complaints w/ Black Suspects  Total Complaints  \
# 3/23-29                             45                77
# 3/30-4/5                            27                73
# 4/6-12                              50                88
# 4/13-19                             47                96
# 4/20-26                             42                75
# 4/27-5/3                            42                70
# 5/4-10                              48                85
# 5/11-17                             54                93
#
#           Percentage of Black-Suspect Complaints  \
# 3/23-29                                58.441558
# 3/30-4/5                               36.986301
# 4/6-12                                 56.818182
# 4/13-19                                48.958333
# 4/20-26                                56.000000
# 4/27-5/3                               60.000000
# 5/4-10                                 56.470588
# 5/11-17                                58.064516
#
# ...

# %% [markdown]
# ### Manhattan

# %%
display(grayDFm)
# Out:
#           Complaints w/ Black Suspects  Total Complaints  \
# 3/23-29                            455               972
# 3/30-4/5                           489              1074
# 4/6-12                             514              1038
# 4/13-19                            557              1162
# 4/20-26                            540              1069
# 4/27-5/3                           502              1062
# 5/4-10                             561              1124
# 5/11-17                            547              1130
#
#           Percentage of Black-Suspect Complaints  \
# 3/23-29                                46.810700
# 3/30-4/5                               45.530726
# 4/6-12                                 49.518304
# 4/13-19                                47.934596
# 4/20-26                                50.514500
# 4/27-5/3                               47.269303
# 5/4-10                                 49.911032
# 5/11-17                                48.407080
#
# ...

# %% [markdown]
# ## Death of George Floyd (2020)

# %% [markdown]
# ### Manhattan CD9

# %%
display(floydDFcd9)
# Out:
#           Complaints w/ Black Suspects  Total Complaints  \
# 4/28-5/4                            33                55
# 5/5-11                              31                48
# 5/12-18                             48                75
# 5/19-25                             45                74
# 5/26-6/1                            36                65
# 6/2-8                               33                56
# 6/9-15                              26                57
# 6/16-22                             32                53
#
#           Percentage of Black-Suspect Complaints  \
# 4/28-5/4                               60.000000
# 5/5-11                                 64.583333
# 5/12-18                                64.000000
# 5/19-25                                60.810811
# 5/26-6/1                               55.384615
# 6/2-8                                  58.928571
# 6/9-15                                 45.614035
# 6/16-22                                60.377358
#
# ...

# %% [markdown]
# ### Manhattan

# %%
display(floydDFm)
# Out:
#           Complaints w/ Black Suspects  Total Complaints  \
# 4/28-5/4                           406               791
# 5/5-11                             366               719
# 5/12-18                            416               840
# 5/19-25                            434               863
# 5/26-6/1                           563              1036
# 6/2-8                              485               812
# 6/9-15                             436               845
# 6/16-22                            446               840
#
#           Percentage of Black-Suspect Complaints  \
# 4/28-5/4                               51.327434
# 5/5-11                                 50.904033
# 5/12-18                                49.523810
# 5/19-25                                50.289687
# 5/26-6/1                               54.343629
# 6/2-8                                  59.729064
# 6/9-15                                 51.597633
# 6/16-22                                53.095238
#
# ...

# %%
import pandas as pd
weekList=['week1','week2','week3','week4','week5','week6','week7','week8']
yearList=['2010','2011','2012','2013','2014','2015','2016','2017','2018','2019','Total/Average']

# %%
arrcd9=[]
barrcd9=[]
compcd9=[]
bcompcd9=[]
arrM=[]
barrM=[]
compM=[]
bcompM=[]
pbarrcd9=[]
pbcompcd9=[]
pbarrm=[]
pbcompm=[]
weeks=['2/13-19','2/20-26','2/27-3/4','3/5-11','3/12-18','3/19-25','3/26-4/1','4/2-4/8']
for x in range(len(weekList)):
    #CD9
    arrDF = pd.read_json(r'JSONs/Arrests/Martin2012/cd9/'+weekList[x]+'.json')
    arrDF = arrDF[arrDF.PERP_RACE!='UNKNOWN']
    arrDF= arrDF.dropna()
    arrcd9.append(len(arrDF))
    arrDF=arrDF[arrDF.PERP_RACE=='BLACK']
    barrcd9.append(len(arrDF))
    compDF = pd.read_json(r'JSONs/Complaints/Martin2012/cd9/'+weekList[x]+'.json')
    compDF = compDF[compDF.SUSP_RACE!='UNKNOWN']
    compDF = compDF.dropna()
    compcd9.append(len(compDF))
    compDF=compDF[compDF.SUSP_RACE=='BLACK']
    bcompcd9.append(len(compDF))
    pbarrcd9.append(barrcd9[len(barrcd9)-1]/arrcd9[len(arrcd9)-1]*100)
    pbcompcd9.append(bcompcd9[len(bcompcd9)-1]/compcd9[len(compcd9)-1]*100)
    #Manhattan
    arrDF = pd.read_json(r'JSONs/Arrests/Martin2012/manhattan/'+weekList[x]+'.json')
    arrDF = arrDF[arrDF.PERP_RACE!='UNKNOWN']
    arrDF= arrDF.dropna()
    arrM.append(len(arrDF))
    arrDF=arrDF[arrDF.PERP_RACE=='BLACK']
    barrM.append(len(arrDF))
    compDF = pd.read_json(r'JSONs/Complaints/Martin2012/manhattan/'+weekList[x]+'.json')
    compDF = compDF[compDF.SUSP_RACE!='UNKNOWN']
    compDF = compDF.dropna()
    compM.append(len(compDF))
    compDF=compDF[compDF.SUSP_RACE=='BLACK']
    bcompM.append(len(compDF))
    pbarrm.append(barrM[len(barrcd9)-1]/arrM[len(arrcd9)-1]*100)
    pbcompm.append(bcompM[len(bcompcd9)-1]/compM[len(compcd9)-1]*100)
d={'Complaints w/ Black Suspects':bcompcd9,'Total Complaints':compcd9,'Percentage of Black-Suspect Complaints':pbcompcd9,'Arrests w/ Black Perpetrators':barrcd9,'Total Arrests':arrcd9,'Percentage of Black-Perpetrator Arrests':pbarrcd9}
e={'Complaints w/ Black Suspects':bcompM,'Total Complaints':compM,'Percentage of Black-Suspect Complaints':pbcompm,'Arrests w/ Black Perpetrators':barrM,'Total Arrests':arrM,'Percentage of Black-Perpetrator Arrests':pbarrm}
martinDFcd9=pd.DataFrame(data=d,index=weeks)
martinDFm=pd.DataFrame(data=e,index=weeks)

# %%
arrcd9=[]
barrcd9=[]
compcd9=[]
bcompcd9=[]
arrM=[]
barrM=[]
compM=[]
bcompM=[]
pbarrcd9=[]
pbcompcd9=[]
pbarrm=[]
pbcompm=[]
weeks=['6/16-22','6/23-29','6/30-7/6','7/7-13','7/14-20','7/21-27','7/28-8/3','8/4-10']
for x in range(len(weekList)):
    #CD9
    arrDF = pd.read_json(r'JSONs/Arrests/Zimmerman2013/cd9/'+weekList[x]+'.json')
    arrDF = arrDF[arrDF.PERP_RACE!='UNKNOWN']
    arrDF= arrDF.dropna()
    arrcd9.append(len(arrDF))
    arrDF=arrDF[arrDF.PERP_RACE=='BLACK']
    barrcd9.append(len(arrDF))
    compDF = pd.read_json(r'JSONs/Complaints/Zimmerman2013/cd9/'+weekList[x]+'.json')
    compDF = compDF[compDF.SUSP_RACE!='UNKNOWN']
    compDF = compDF.dropna()
    compcd9.append(len(compDF))
    compDF=compDF[compDF.SUSP_RACE=='BLACK']
    bcompcd9.append(len(compDF))
    pbarrcd9.append(barrcd9[len(barrcd9)-1]/arrcd9[len(arrcd9)-1]*100)
    pbcompcd9.append(bcompcd9[len(bcompcd9)-1]/compcd9[len(compcd9)-1]*100)
    #Manhattan
    arrDF = pd.read_json(r'JSONs/Arrests/Zimmerman2013/manhattan/'+weekList[x]+'.json')
    arrDF = arrDF[arrDF.PERP_RACE!='UNKNOWN']
    arrDF= arrDF.dropna()
    arrM.append(len(arrDF))
    arrDF=arrDF[arrDF.PERP_RACE=='BLACK']
    barrM.append(len(arrDF))
    compDF = pd.read_json(r'JSONs/Complaints/Zimmerman2013/manhattan/'+weekList[x]+'.json')
    compDF = compDF[compDF.SUSP_RACE!='UNKNOWN']
    compDF = compDF.dropna()
    compM.append(len(compDF))
    compDF=compDF[compDF.SUSP_RACE=='BLACK']
    bcompM.append(len(compDF))
    pbarrm.append(barrM[len(barrcd9)-1]/arrM[len(arrcd9)-1]*100)
    pbcompm.append(bcompM[len(bcompcd9)-1]/compM[len(compcd9)-1]*100)
d={'Complaints w/ Black Suspects':bcompcd9,'Total Complaints':compcd9,'Percentage of Black-Suspect Complaints':pbcompcd9,'Arrests w/ Black Perpetrators':barrcd9,'Total Arrests':arrcd9,'Percentage of Black-Perpetrator Arrests':pbarrcd9}
e={'Complaints w/ Black Suspects':bcompM,'Total Complaints':compM,'Percentage of Black-Suspect Complaints':pbcompm,'Arrests w/ Black Perpetrators':barrM,'Total Arrests':arrM,'Percentage of Black-Perpetrator Arrests':pbarrm}
zimmermanDFcd9=pd.DataFrame(data=d,index=weeks)
zimmermanDFm=pd.DataFrame(data=e,index=weeks)

# %%
arrcd9=[]
barrcd9=[]
compcd9=[]
bcompcd9=[]
arrM=[]
barrM=[]
compM=[]
bcompM=[]
pbarrcd9=[]
pbcompcd9=[]
pbarrm=[]
pbcompm=[]
weeks=['10/28-11/3','11/4-10','11/11-17','11/18-24','11/25-12/1','12/2-8','12/9-15','12/16-22']
for x in range(len(weekList)):
    #CD9
    arrDF = pd.read_json(r'JSONs/Arrests/Ferguson2014/cd9/'+weekList[x]+'.json')
    arrDF = arrDF[arrDF.PERP_RACE!='UNKNOWN']
    arrDF= arrDF.dropna()
    arrcd9.append(len(arrDF))
    arrDF=arrDF[arrDF.PERP_RACE=='BLACK']
    barrcd9.append(len(arrDF))
    compDF = pd.read_json(r'JSONs/Complaints/Ferguson2014/cd9/'+weekList[x]+'.json')
    compDF = compDF[compDF.SUSP_RACE!='UNKNOWN']
    compDF = compDF.dropna()
    compcd9.append(len(compDF))
    compDF=compDF[compDF.SUSP_RACE=='BLACK']
    bcompcd9.append(len(compDF))
    pbarrcd9.append(barrcd9[len(barrcd9)-1]/arrcd9[len(arrcd9)-1]*100)
    pbcompcd9.append(bcompcd9[len(bcompcd9)-1]/compcd9[len(compcd9)-1]*100)
    #Manhattan
    arrDF = pd.read_json(r'JSONs/Arrests/Ferguson2014/manhattan/'+weekList[x]+'.json')
    arrDF = arrDF[arrDF.PERP_RACE!='UNKNOWN']
    arrDF= arrDF.dropna()
    arrM.append(len(arrDF))
    arrDF=arrDF[arrDF.PERP_RACE=='BLACK']
    barrM.append(len(arrDF))
    compDF = pd.read_json(r'JSONs/Complaints/Ferguson2014/manhattan/'+weekList[x]+'.json')
    compDF = compDF[compDF.SUSP_RACE!='UNKNOWN']
    compDF = compDF.dropna()
    compM.append(len(compDF))
    compDF=compDF[compDF.SUSP_RACE=='BLACK']
    bcompM.append(len(compDF))
    pbarrm.append(barrM[len(barrcd9)-1]/arrM[len(arrcd9)-1]*100)
    pbcompm.append(bcompM[len(bcompcd9)-1]/compM[len(compcd9)-1]*100)
d={'Complaints w/ Black Suspects':bcompcd9,'Total Complaints':compcd9,'Percentage of Black-Suspect Complaints':pbcompcd9,'Arrests w/ Black Perpetrators':barrcd9,'Total Arrests':arrcd9,'Percentage of Black-Perpetrator Arrests':pbarrcd9}
e={'Complaints w/ Black Suspects':bcompM,'Total Complaints':compM,'Percentage of Black-Suspect Complaints':pbcompm,'Arrests w/ Black Perpetrators':barrM,'Total Arrests':arrM,'Percentage of Black-Perpetrator Arrests':pbarrm}
fergusonDFcd9=pd.DataFrame(data=d,index=weeks)
fergusonDFm=pd.DataFrame(data=e,index=weeks)

# %%
arrcd9=[]
barrcd9=[]
compcd9=[]
bcompcd9=[]
arrM=[]
barrM=[]
compM=[]
bcompM=[]
pbarrcd9=[]
pbcompcd9=[]
pbarrm=[]
pbcompm=[]
weeks=['3/23-29','3/30-4/5','4/6-12','4/13-19','4/20-26','4/27-5/3','5/4-10','5/11-17']
for x in range(len(weekList)):
    #CD9
    arrDF = pd.read_json(r'JSONs/Arrests/Gray2015/cd9/'+weekList[x]+'.json')
    arrDF = arrDF[arrDF.PERP_RACE!='UNKNOWN']
    arrDF= arrDF.dropna()
    arrcd9.append(len(arrDF))
    arrDF=arrDF[arrDF.PERP_RACE=='BLACK']
    barrcd9.append(len(arrDF))
    compDF = pd.read_json(r'JSONs/Complaints/Gray2015/cd9/'+weekList[x]+'.json')
    compDF = compDF[compDF.SUSP_RACE!='UNKNOWN']
    compDF = compDF.dropna()
    compcd9.append(len(compDF))
    compDF=compDF[compDF.SUSP_RACE=='BLACK']
    bcompcd9.append(len(compDF))
    pbarrcd9.append(barrcd9[len(barrcd9)-1]/arrcd9[len(arrcd9)-1]*100)
    pbcompcd9.append(bcompcd9[len(bcompcd9)-1]/compcd9[len(compcd9)-1]*100)
    #Manhattan
    arrDF = pd.read_json(r'JSONs/Arrests/Gray2015/manhattan/'+weekList[x]+'.json')
    arrDF = arrDF[arrDF.PERP_RACE!='UNKNOWN']
    arrDF= arrDF.dropna()
    arrM.append(len(arrDF))
    arrDF=arrDF[arrDF.PERP_RACE=='BLACK']
    barrM.append(len(arrDF))
    compDF = pd.read_json(r'JSONs/Complaints/Gray2015/manhattan/'+weekList[x]+'.json')
    compDF = compDF[compDF.SUSP_RACE!='UNKNOWN']
    compDF = compDF.dropna()
    compM.append(len(compDF))
    compDF=compDF[compDF.SUSP_RACE=='BLACK']
    bcompM.append(len(compDF))
    pbarrm.append(barrM[len(barrcd9)-1]/arrM[len(arrcd9)-1]*100)
    pbcompm.append(bcompM[len(bcompcd9)-1]/compM[len(compcd9)-1]*100)
d={'Complaints w/ Black Suspects':bcompcd9,'Total Complaints':compcd9,'Percentage of Black-Suspect Complaints':pbcompcd9,'Arrests w/ Black Perpetrators':barrcd9,'Total Arrests':arrcd9,'Percentage of Black-Perpetrator Arrests':pbarrcd9}
e={'Complaints w/ Black Suspects':bcompM,'Total Complaints':compM,'Percentage of Black-Suspect Complaints':pbcompm,'Arrests w/ Black Perpetrators':barrM,'Total Arrests':arrM,'Percentage of Black-Perpetrator Arrests':pbarrm}
grayDFcd9=pd.DataFrame(data=d,index=weeks)
grayDFm=pd.DataFrame(data=e,index=weeks)

# %%
arrcd9=[]
barrcd9=[]
compcd9=[]
bcompcd9=[]
arrM=[]
barrM=[]
compM=[]
bcompM=[]
pbarrcd9=[]
pbcompcd9=[]
pbarrm=[]
pbcompm=[]
weeks=['4/28-5/4','5/5-11','5/12-18','5/19-25','5/26-6/1','6/2-8','6/9-15','6/16-22']
for x in range(len(weekList)):
    #CD9
    arrDF = pd.read_json(r'JSONs/Arrests/Floyd2020/cd9/'+weekList[x]+'.json')
    arrDF = arrDF[arrDF.PERP_RACE!='UNKNOWN']
    arrDF= arrDF.dropna()
    arrcd9.append(len(arrDF))
    arrDF=arrDF[arrDF.PERP_RACE=='BLACK']
    barrcd9.append(len(arrDF))
    compDF = pd.read_json(r'JSONs/Complaints/Floyd2020/cd9/'+weekList[x]+'.json')
    compDF = compDF[compDF.SUSP_RACE!='UNKNOWN']
    compDF = compDF.dropna()
    compcd9.append(len(compDF))
    compDF=compDF[compDF.SUSP_RACE=='BLACK']
    bcompcd9.append(len(compDF))
    pbarrcd9.append(barrcd9[len(barrcd9)-1]/arrcd9[len(arrcd9)-1]*100)
    pbcompcd9.append(bcompcd9[len(bcompcd9)-1]/compcd9[len(compcd9)-1]*100)
    #Manhattan
    arrDF = pd.read_json(r'JSONs/Arrests/Floyd2020/manhattan/'+weekList[x]+'.json')
    arrDF = arrDF[arrDF.PERP_RACE!='UNKNOWN']
    arrDF= arrDF.dropna()
    arrM.append(len(arrDF))
    arrDF=arrDF[arrDF.PERP_RACE=='BLACK']
    barrM.append(len(arrDF))
    compDF = pd.read_json(r'JSONs/Complaints/Floyd2020/manhattan/'+weekList[x]+'.json')
    compDF = compDF[compDF.SUSP_RACE!='UNKNOWN']
    compDF = compDF.dropna()
    compM.append(len(compDF))
    compDF=compDF[compDF.SUSP_RACE=='BLACK']
    bcompM.append(len(compDF))
    pbarrm.append(barrM[len(barrcd9)-1]/arrM[len(arrcd9)-1]*100)
    pbcompm.append(bcompM[len(bcompcd9)-1]/compM[len(compcd9)-1]*100)
d={'Complaints w/ Black Suspects':bcompcd9,'Total Complaints':compcd9,'Percentage of Black-Suspect Complaints':pbcompcd9,'Arrests w/ Black Perpetrators':barrcd9,'Total Arrests':arrcd9,'Percentage of Black-Perpetrator Arrests':pbarrcd9}
e={'Complaints w/ Black Suspects':bcompM,'Total Complaints':compM,'Percentage of Black-Suspect Complaints':pbcompm,'Arrests w/ Black Perpetrators':barrM,'Total Arrests':arrM,'Percentage of Black-Perpetrator Arrests':pbarrm}
floydDFcd9=pd.DataFrame(data=d,index=weeks)
floydDFm=pd.DataFrame(data=e,index=weeks)

# %%
compcd9=[]
bcompcd9=[]
wcompcd9=[]
pbcompcd9=[]
pwcompcd9=[]
totcd9=0
totbcd9=0
totwcd9=0
for x in range(len(yearList)-1):
    #Black
    arrDF = pd.read_json(r'JSONs/Complaints/Yearly/cd9/'+yearList[x]+'.json')
    arrDF = arrDF[arrDF.SUSP_RACE!='UNKNOWN']
    arrDF= arrDF.dropna()
    compcd9.append(len(arrDF))
    totcd9+=len(arrDF)
    arrDF=arrDF[arrDF.SUSP_RACE=='BLACK']
    bcompcd9.append(len(arrDF))
    totbcd9+=len(arrDF)
    pbcompcd9.append(bcompcd9[len(bcompcd9)-1]/compcd9[len(compcd9)-1]*100)
    arrDF = pd.read_json(r'JSONs/Complaints/Yearly/cd9/'+yearList[x]+'.json')
    arrDF = arrDF[arrDF.SUSP_RACE!='UNKNOWN']
    arrDF= arrDF.dropna()
    arrDF=arrDF[arrDF.SUSP_RACE=='WHITE']
    wcompcd9.append(len(arrDF))
    totwcd9+=len(arrDF)
    pwcompcd9.append(wcompcd9[len(bcompcd9)-1]/compcd9[len(compcd9)-1]*100)
compcd9.append(totcd9)
bcompcd9.append(totbcd9)
wcompcd9.append(totwcd9)
pbcompcd9.append(totbcd9/totcd9*100)
pwcompcd9.append(totwcd9/totcd9*100)

d={'Total Complaints':compcd9,'Complaints w/ Black Suspects':bcompcd9,'Percentage of Black-Suspect Complaints':pbcompcd9,'Complaints w/ White Suspects':wcompcd9,'Percentage of White-Suspect Complaints':pwcompcd9}
cd9Years=pd.DataFrame(data=d,index=yearList)

# %%
compcd11=[]
bcompcd11=[]
wcompcd11=[]
pbcompcd11=[]
pwcompcd11=[]
totcd11=0
totbcd11=0
totwcd11=0
for x in range(len(yearList)-1):
    #Black
    arrDF = pd.read_json(r'JSONs/Complaints/Yearly/cd11/'+yearList[x]+'.json')
    arrDF = arrDF[arrDF.SUSP_RACE!='UNKNOWN']
    arrDF= arrDF.dropna()
    compcd11.append(len(arrDF))
    totcd11+=len(arrDF)
    arrDF=arrDF[arrDF.SUSP_RACE=='BLACK']
    bcompcd11.append(len(arrDF))
    totbcd11+=len(arrDF)
    pbcompcd11.append(bcompcd11[len(bcompcd11)-1]/compcd11[len(compcd11)-1]*100)
    arrDF = pd.read_json(r'JSONs/Complaints/Yearly/cd11/'+yearList[x]+'.json')
    arrDF = arrDF[arrDF.SUSP_RACE!='UNKNOWN']
    arrDF= arrDF.dropna()
    arrDF=arrDF[arrDF.SUSP_RACE=='WHITE']
    wcompcd11.append(len(arrDF))
    totwcd11+=len(arrDF)
    pwcompcd11.append(wcompcd11[len(bcompcd11)-1]/compcd11[len(compcd11)-1]*100)
compcd11.append(totcd11)
bcompcd11.append(totbcd11)
wcompcd11.append(totwcd11)
pbcompcd11.append(totbcd11/totcd11*100)
pwcompcd11.append(totwcd11/totcd11*100)

d={'Total Complaints':compcd11,'Complaints w/ Black Suspects':bcompcd11,'Percentage of Black-Suspect Complaints':pbcompcd11,'Complaints w/ White Suspects':wcompcd11,'Percentage of White-Suspect Complaints':pwcompcd11}
cd11Years=pd.DataFrame(data=d,index=yearList)

# %%
compmanhattan=[]
bcompmanhattan=[]
wcompmanhattan=[]
pbcompmanhattan=[]
pwcompmanhattan=[]
totmanhattan=0
totbmanhattan=0
totwmanhattan=0
for x in range(len(yearList)-1):
    #Black
    arrDF = pd.read_json(r'JSONs/Complaints/Yearly/manhattan/'+yearList[x]+'.json')
    arrDF = arrDF[arrDF.SUSP_RACE!='UNKNOWN']
    arrDF= arrDF.dropna()
    compmanhattan.append(len(arrDF))
    totmanhattan+=len(arrDF)
    arrDF=arrDF[arrDF.SUSP_RACE=='BLACK']
    bcompmanhattan.append(len(arrDF))
    totbmanhattan+=len(arrDF)
    pbcompmanhattan.append(bcompmanhattan[len(bcompmanhattan)-1]/compmanhattan[len(compmanhattan)-1]*100)
    arrDF = pd.read_json(r'JSONs/Complaints/Yearly/manhattan/'+yearList[x]+'.json')
    arrDF = arrDF[arrDF.SUSP_RACE!='UNKNOWN']
    arrDF= arrDF.dropna()
    arrDF=arrDF[arrDF.SUSP_RACE=='WHITE']
    wcompmanhattan.append(len(arrDF))
    totwmanhattan+=len(arrDF)
    pwcompmanhattan.append(wcompmanhattan[len(bcompmanhattan)-1]/compmanhattan[len(compmanhattan)-1]*100)
compmanhattan.append(totmanhattan)
bcompmanhattan.append(totbmanhattan)
wcompmanhattan.append(totwmanhattan)
pbcompmanhattan.append(totbmanhattan/totmanhattan*100)
pwcompmanhattan.append(totwmanhattan/totmanhattan*100)
d={'Total Complaints':compmanhattan,'Complaints w/ Black Suspects':bcompmanhattan,'Percentage of Black-Suspect Complaints':pbcompmanhattan,'Complaints w/ White Suspects':wcompmanhattan,'Percentage of White-Suspect Complaints':pwcompmanhattan}
manhattanYears=pd.DataFrame(data=d,index=yearList)
