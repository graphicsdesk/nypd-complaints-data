# %%
display(martinDFcd9)

# %%
display(martinDFm)
# Out:
#    Complaints w/ Black Suspects  Total Complaints  \
# 0                           258               574
# 1                           215               535
# 2                           313               583
# 3                           259               544
# 4                           301               634
# 5                           310               637
# 6                           316               609
# 7                           281               584
#
#    Percentage of Black-Suspect Complaints  Arrests w/ Black Perpetrators  \
# 0                               44.947735                            925
# 1                               40.186916                            982
# 2                               53.687822                            897
# 3                               47.610294                           1206
# 4                               47.476341                           1094
# 5                               48.665620                           1059
# 6                               51.888342                           1009
# 7                               48.116438                           1117
#
#    Total Arrests  Percentage of Black-Perpetrator Arrests
# 0           2101                                44.026654
# 1           2044                                48.043053
# 2           1891                                47.435219
# 3           2548                                47.331240
# 4           2396                                45.659432
# 5           2353                                45.006375
# 6           2177                                46.348186
# 7           2308                                48.396880

# %%
display(zimmermanDFcd9)

# %%
display(zimmermanDFm)
# Out:
#    Complaints w/ Black Suspects  Total Complaints  \
# 0                           337               691
# 1                           343               654
# 2                           257               568
# 3                           345               657
# 4                           353               668
# 5                           344               696
# 6                           334               647
# 7                           322               636
#
#    Percentage of Black-Suspect Complaints  Arrests w/ Black Perpetrators  \
# 0                               48.769899                            983
# 1                               52.446483                            886
# 2                               45.246479                            839
# 3                               52.511416                            939
# 4                               52.844311                            910
# 5                               49.425287                            968
# 6                               51.622875                           1001
# 7                               50.628931                           1001
#
#    Total Arrests  Percentage of Black-Perpetrator Arrests
# 0           2089                                47.056008
# 1           1951                                45.412609
# 2           1884                                44.532909
# 3           1992                                47.138554
# 4           1965                                46.310433
# 5           2138                                45.275959
# 6           2119                                47.239264
# 7           2117                                47.283892

# %%
display(fergusonDFcd9)

# %%
display(fergusonDFm)
# Out:
#    Complaints w/ Black Suspects  Total Complaints  \
# 0                           495              1067
# 1                           507              1136
# 2                           510              1037
# 3                           501              1044
# 4                           444               893
# 5                           405               921
# 6                           452               969
# 7                           449               914
#
#    Percentage of Black-Suspect Complaints  Arrests w/ Black Perpetrators  \
# 0                               46.391753                            839
# 1                               44.630282                            960
# 2                               49.180328                            926
# 3                               47.988506                            929
# 4                               49.720045                            614
# 5                               43.973941                            714
# 6                               46.646027                            709
# 7                               49.124726                            583
#
#    Total Arrests  Percentage of Black-Perpetrator Arrests
# 0           1827                                45.922277
# 1           2047                                46.897899
# 2           2062                                44.907856
# 3           2051                                45.294978
# 4           1364                                45.014663
# 5           1613                                44.265344
# 6           1565                                45.303514
# 7           1313                                44.402133

# %%
display(grayDFcd9)

# %%
display(grayDFm)
# Out:
#    Complaints w/ Black Suspects  Total Complaints  \
# 0                           258               574
# 1                           215               535
# 2                           313               583
# 3                           259               544
# 4                           301               634
# 5                           310               637
# 6                           316               609
# 7                           281               584
#
#    Percentage of Black-Suspect Complaints  Arrests w/ Black Perpetrators  \
# 0                               44.947735                            925
# 1                               40.186916                            982
# 2                               53.687822                            897
# 3                               47.610294                           1206
# 4                               47.476341                           1094
# 5                               48.665620                           1059
# 6                               51.888342                           1009
# 7                               48.116438                           1117
#
#    Total Arrests  Percentage of Black-Perpetrator Arrests
# 0           2101                                44.026654
# 1           2044                                48.043053
# 2           1891                                47.435219
# 3           2548                                47.331240
# 4           2396                                45.659432
# 5           2353                                45.006375
# 6           2177                                46.348186
# 7           2308                                48.396880

# %%
display(floydDFcd9)

# %%
display(floydDFm)
# Out:
#    Complaints w/ Black Suspects  Total Complaints  \
# 0                           460               887
# 1                           366               719
# 2                           416               840
# 3                           434               863
# 4                           563              1036
# 5                           485               812
# 6                           436               845
# 7                           446               840
#
#    Percentage of Black-Suspect Complaints  Arrests w/ Black Perpetrators  \
# 0                               51.860203                            350
# 1                               50.904033                            282
# 2                               49.523810                            363
# 3                               50.289687                            368
# 4                               54.343629                            726
# 5                               59.729064                            319
# 6                               51.597633                            185
# 7                               53.095238                            173
#
#    Total Arrests  Percentage of Black-Perpetrator Arrests
# 0            661                                52.950076
# 1            539                                52.319109
# 2            728                                49.862637
# 3            734                                50.136240
# 4           1345                                53.977695
# 5            532                                59.962406
# 6            339                                54.572271
# 7            333                                51.951952

# %%
import pandas as pd
weekList=['week1','week2','week3','week4','week5','week6','week7','week8']

# %%
arrcd9=[]
barrcd9=[]
compcd9=[]
bcompcd9=[]
arrM=[]
barrM=[]
compM=[]
bcompM=[]
pbarrcd9=[]
pbcompcd9=[]
pbarrm=[]
pbcompm=[]
for x in range(len(weekList)):
    #CD9
    arrDF = pd.read_json(r'JSONs/Arrests/Martin2012/cd9/'+weekList[x]+'.json')
    arrDF = arrDF[arrDF.PERP_RACE!='UNKNOWN']
    arrDF= arrDF.dropna()
    arrcd9.append(len(arrDF))
    arrDF=arrDF[arrDF.PERP_RACE=='BLACK']
    barrcd9.append(len(arrDF))
    compDF = pd.read_json(r'JSONs/Complaints/Martin2012/cd9/'+weekList[x]+'.json')
    compDF = compDF[compDF.SUSP_RACE!='UNKNOWN']
    compDF = compDF.dropna()
    compcd9.append(len(compDF))
    compDF=compDF[compDF.SUSP_RACE=='BLACK']
    bcompcd9.append(len(compDF))
    pbarrcd9.append(barrcd9[len(barrcd9)-1]/arrcd9[len(arrcd9)-1]*100)
    pbcompcd9.append(bcompcd9[len(bcompcd9)-1]/compcd9[len(compcd9)-1]*100)
    #Manhattan
    arrDF = pd.read_json(r'JSONs/Arrests/Martin2012/manhattan/'+weekList[x]+'.json')
    arrDF = arrDF[arrDF.PERP_RACE!='UNKNOWN']
    arrDF= arrDF.dropna()
    arrM.append(len(arrDF))
    arrDF=arrDF[arrDF.PERP_RACE=='BLACK']
    barrM.append(len(arrDF))
    compDF = pd.read_json(r'JSONs/Complaints/Martin2012/manhattan/'+weekList[x]+'.json')
    compDF = compDF[compDF.SUSP_RACE!='UNKNOWN']
    compDF = compDF.dropna()
    compM.append(len(compDF))
    compDF=compDF[compDF.SUSP_RACE=='BLACK']
    bcompM.append(len(compDF))
    pbarrm.append(barrM[len(barrcd9)-1]/arrM[len(arrcd9)-1]*100)
    pbcompm.append(bcompM[len(bcompcd9)-1]/compM[len(compcd9)-1]*100)
d={'Complaints w/ Black Suspects':bcompcd9,'Total Complaints':compcd9,'Percentage of Black-Suspect Complaints':pbcompcd9,'Arrests w/ Black Perpetrators':barrcd9,'Total Arrests':arrcd9,'Percentage of Black-Perpetrator Arrests':pbarrcd9}
e={'Complaints w/ Black Suspects':bcompM,'Total Complaints':compM,'Percentage of Black-Suspect Complaints':pbcompm,'Arrests w/ Black Perpetrators':barrM,'Total Arrests':arrM,'Percentage of Black-Perpetrator Arrests':pbarrm}
martinDFcd9=pd.DataFrame(data=d)
martinDFm=pd.DataFrame(data=e)

# %%
arrcd9=[]
barrcd9=[]
compcd9=[]
bcompcd9=[]
arrM=[]
barrM=[]
compM=[]
bcompM=[]
pbarrcd9=[]
pbcompcd9=[]
pbarrm=[]
pbcompm=[]
for x in range(len(weekList)):
    #CD9
    arrDF = pd.read_json(r'JSONs/Arrests/Zimmerman2013/cd9/'+weekList[x]+'.json')
    arrDF = arrDF[arrDF.PERP_RACE!='UNKNOWN']
    arrDF= arrDF.dropna()
    arrcd9.append(len(arrDF))
    arrDF=arrDF[arrDF.PERP_RACE=='BLACK']
    barrcd9.append(len(arrDF))
    compDF = pd.read_json(r'JSONs/Complaints/Zimmerman2013/cd9/'+weekList[x]+'.json')
    compDF = compDF[compDF.SUSP_RACE!='UNKNOWN']
    compDF = compDF.dropna()
    compcd9.append(len(compDF))
    compDF=compDF[compDF.SUSP_RACE=='BLACK']
    bcompcd9.append(len(compDF))
    pbarrcd9.append(barrcd9[len(barrcd9)-1]/arrcd9[len(arrcd9)-1]*100)
    pbcompcd9.append(bcompcd9[len(bcompcd9)-1]/compcd9[len(compcd9)-1]*100)
    #Manhattan
    arrDF = pd.read_json(r'JSONs/Arrests/Zimmerman2013/manhattan/'+weekList[x]+'.json')
    arrDF = arrDF[arrDF.PERP_RACE!='UNKNOWN']
    arrDF= arrDF.dropna()
    arrM.append(len(arrDF))
    arrDF=arrDF[arrDF.PERP_RACE=='BLACK']
    barrM.append(len(arrDF))
    compDF = pd.read_json(r'JSONs/Complaints/Zimmerman2013/manhattan/'+weekList[x]+'.json')
    compDF = compDF[compDF.SUSP_RACE!='UNKNOWN']
    compDF = compDF.dropna()
    compM.append(len(compDF))
    compDF=compDF[compDF.SUSP_RACE=='BLACK']
    bcompM.append(len(compDF))
    pbarrm.append(barrM[len(barrcd9)-1]/arrM[len(arrcd9)-1]*100)
    pbcompm.append(bcompM[len(bcompcd9)-1]/compM[len(compcd9)-1]*100)
d={'Complaints w/ Black Suspects':bcompcd9,'Total Complaints':compcd9,'Percentage of Black-Suspect Complaints':pbcompcd9,'Arrests w/ Black Perpetrators':barrcd9,'Total Arrests':arrcd9,'Percentage of Black-Perpetrator Arrests':pbarrcd9}
e={'Complaints w/ Black Suspects':bcompM,'Total Complaints':compM,'Percentage of Black-Suspect Complaints':pbcompm,'Arrests w/ Black Perpetrators':barrM,'Total Arrests':arrM,'Percentage of Black-Perpetrator Arrests':pbarrm}
zimmermanDFcd9=pd.DataFrame(data=d)
zimmermanDFm=pd.DataFrame(data=e)

# %%
arrcd9=[]
barrcd9=[]
compcd9=[]
bcompcd9=[]
arrM=[]
barrM=[]
compM=[]
bcompM=[]
pbarrcd9=[]
pbcompcd9=[]
pbarrm=[]
pbcompm=[]
for x in range(len(weekList)):
    #CD9
    arrDF = pd.read_json(r'JSONs/Arrests/Ferguson2014/cd9/'+weekList[x]+'.json')
    arrDF = arrDF[arrDF.PERP_RACE!='UNKNOWN']
    arrDF= arrDF.dropna()
    arrcd9.append(len(arrDF))
    arrDF=arrDF[arrDF.PERP_RACE=='BLACK']
    barrcd9.append(len(arrDF))
    compDF = pd.read_json(r'JSONs/Complaints/Ferguson2014/cd9/'+weekList[x]+'.json')
    compDF = compDF[compDF.SUSP_RACE!='UNKNOWN']
    compDF = compDF.dropna()
    compcd9.append(len(compDF))
    compDF=compDF[compDF.SUSP_RACE=='BLACK']
    bcompcd9.append(len(compDF))
    pbarrcd9.append(barrcd9[len(barrcd9)-1]/arrcd9[len(arrcd9)-1]*100)
    pbcompcd9.append(bcompcd9[len(bcompcd9)-1]/compcd9[len(compcd9)-1]*100)
    #Manhattan
    arrDF = pd.read_json(r'JSONs/Arrests/Ferguson2014/manhattan/'+weekList[x]+'.json')
    arrDF = arrDF[arrDF.PERP_RACE!='UNKNOWN']
    arrDF= arrDF.dropna()
    arrM.append(len(arrDF))
    arrDF=arrDF[arrDF.PERP_RACE=='BLACK']
    barrM.append(len(arrDF))
    compDF = pd.read_json(r'JSONs/Complaints/Ferguson2014/manhattan/'+weekList[x]+'.json')
    compDF = compDF[compDF.SUSP_RACE!='UNKNOWN']
    compDF = compDF.dropna()
    compM.append(len(compDF))
    compDF=compDF[compDF.SUSP_RACE=='BLACK']
    bcompM.append(len(compDF))
    pbarrm.append(barrM[len(barrcd9)-1]/arrM[len(arrcd9)-1]*100)
    pbcompm.append(bcompM[len(bcompcd9)-1]/compM[len(compcd9)-1]*100)
d={'Complaints w/ Black Suspects':bcompcd9,'Total Complaints':compcd9,'Percentage of Black-Suspect Complaints':pbcompcd9,'Arrests w/ Black Perpetrators':barrcd9,'Total Arrests':arrcd9,'Percentage of Black-Perpetrator Arrests':pbarrcd9}
e={'Complaints w/ Black Suspects':bcompM,'Total Complaints':compM,'Percentage of Black-Suspect Complaints':pbcompm,'Arrests w/ Black Perpetrators':barrM,'Total Arrests':arrM,'Percentage of Black-Perpetrator Arrests':pbarrm}
fergusonDFcd9=pd.DataFrame(data=d)
fergusonDFm=pd.DataFrame(data=e)

# %%
arrcd9=[]
barrcd9=[]
compcd9=[]
bcompcd9=[]
arrM=[]
barrM=[]
compM=[]
bcompM=[]
pbarrcd9=[]
pbcompcd9=[]
pbarrm=[]
pbcompm=[]
for x in range(len(weekList)):
    #CD9
    arrDF = pd.read_json(r'JSONs/Arrests/Martin2012/cd9/'+weekList[x]+'.json')
    arrDF = arrDF[arrDF.PERP_RACE!='UNKNOWN']
    arrDF= arrDF.dropna()
    arrcd9.append(len(arrDF))
    arrDF=arrDF[arrDF.PERP_RACE=='BLACK']
    barrcd9.append(len(arrDF))
    compDF = pd.read_json(r'JSONs/Complaints/Martin2012/cd9/'+weekList[x]+'.json')
    compDF = compDF[compDF.SUSP_RACE!='UNKNOWN']
    compDF = compDF.dropna()
    compcd9.append(len(compDF))
    compDF=compDF[compDF.SUSP_RACE=='BLACK']
    bcompcd9.append(len(compDF))
    pbarrcd9.append(barrcd9[len(barrcd9)-1]/arrcd9[len(arrcd9)-1]*100)
    pbcompcd9.append(bcompcd9[len(bcompcd9)-1]/compcd9[len(compcd9)-1]*100)
    #Manhattan
    arrDF = pd.read_json(r'JSONs/Arrests/Martin2012/manhattan/'+weekList[x]+'.json')
    arrDF = arrDF[arrDF.PERP_RACE!='UNKNOWN']
    arrDF= arrDF.dropna()
    arrM.append(len(arrDF))
    arrDF=arrDF[arrDF.PERP_RACE=='BLACK']
    barrM.append(len(arrDF))
    compDF = pd.read_json(r'JSONs/Complaints/Martin2012/manhattan/'+weekList[x]+'.json')
    compDF = compDF[compDF.SUSP_RACE!='UNKNOWN']
    compDF = compDF.dropna()
    compM.append(len(compDF))
    compDF=compDF[compDF.SUSP_RACE=='BLACK']
    bcompM.append(len(compDF))
    pbarrm.append(barrM[len(barrcd9)-1]/arrM[len(arrcd9)-1]*100)
    pbcompm.append(bcompM[len(bcompcd9)-1]/compM[len(compcd9)-1]*100)
d={'Complaints w/ Black Suspects':bcompcd9,'Total Complaints':compcd9,'Percentage of Black-Suspect Complaints':pbcompcd9,'Arrests w/ Black Perpetrators':barrcd9,'Total Arrests':arrcd9,'Percentage of Black-Perpetrator Arrests':pbarrcd9}
e={'Complaints w/ Black Suspects':bcompM,'Total Complaints':compM,'Percentage of Black-Suspect Complaints':pbcompm,'Arrests w/ Black Perpetrators':barrM,'Total Arrests':arrM,'Percentage of Black-Perpetrator Arrests':pbarrm}
grayDFcd9=pd.DataFrame(data=d)
grayDFm=pd.DataFrame(data=e)

# %%
arrcd9=[]
barrcd9=[]
compcd9=[]
bcompcd9=[]
arrM=[]
barrM=[]
compM=[]
bcompM=[]
pbarrcd9=[]
pbcompcd9=[]
pbarrm=[]
pbcompm=[]
for x in range(len(weekList)):
    #CD9
    arrDF = pd.read_json(r'JSONs/Arrests/Floyd2020/cd9/'+weekList[x]+'.json')
    arrDF = arrDF[arrDF.PERP_RACE!='UNKNOWN']
    arrDF= arrDF.dropna()
    arrcd9.append(len(arrDF))
    arrDF=arrDF[arrDF.PERP_RACE=='BLACK']
    barrcd9.append(len(arrDF))
    compDF = pd.read_json(r'JSONs/Complaints/Floyd2020/cd9/'+weekList[x]+'.json')
    compDF = compDF[compDF.SUSP_RACE!='UNKNOWN']
    compDF = compDF.dropna()
    compcd9.append(len(compDF))
    compDF=compDF[compDF.SUSP_RACE=='BLACK']
    bcompcd9.append(len(compDF))
    pbarrcd9.append(barrcd9[len(barrcd9)-1]/arrcd9[len(arrcd9)-1]*100)
    pbcompcd9.append(bcompcd9[len(bcompcd9)-1]/compcd9[len(compcd9)-1]*100)
    #Manhattan
    arrDF = pd.read_json(r'JSONs/Arrests/Floyd2020/manhattan/'+weekList[x]+'.json')
    arrDF = arrDF[arrDF.PERP_RACE!='UNKNOWN']
    arrDF= arrDF.dropna()
    arrM.append(len(arrDF))
    arrDF=arrDF[arrDF.PERP_RACE=='BLACK']
    barrM.append(len(arrDF))
    compDF = pd.read_json(r'JSONs/Complaints/Floyd2020/manhattan/'+weekList[x]+'.json')
    compDF = compDF[compDF.SUSP_RACE!='UNKNOWN']
    compDF = compDF.dropna()
    compM.append(len(compDF))
    compDF=compDF[compDF.SUSP_RACE=='BLACK']
    bcompM.append(len(compDF))
    pbarrm.append(barrM[len(barrcd9)-1]/arrM[len(arrcd9)-1]*100)
    pbcompm.append(bcompM[len(bcompcd9)-1]/compM[len(compcd9)-1]*100)
d={'Complaints w/ Black Suspects':bcompcd9,'Total Complaints':compcd9,'Percentage of Black-Suspect Complaints':pbcompcd9,'Arrests w/ Black Perpetrators':barrcd9,'Total Arrests':arrcd9,'Percentage of Black-Perpetrator Arrests':pbarrcd9}
e={'Complaints w/ Black Suspects':bcompM,'Total Complaints':compM,'Percentage of Black-Suspect Complaints':pbcompm,'Arrests w/ Black Perpetrators':barrM,'Total Arrests':arrM,'Percentage of Black-Perpetrator Arrests':pbarrm}
floydDFcd9=pd.DataFrame(data=d)
floydDFm=pd.DataFrame(data=e)
