# %%
import json
import requests

# %%
#Martin2012Arrests
date1=['2012-02-13','2012-02-20','2012-02-27','2012-03-05','2012-03-12','2012-03-19','2012-03-26','2012-04-02']
date2=['2012-02-20','2012-02-27','2012-03-05','2012-03-12','2012-03-19','2012-03-26','2012-04-02','2012-04-09']
names=['week1.json','week2.json','week3.json','week4.json','week5.json','week6.json','week7.json','week8.json']
for i in range(len(date1)):    
    arrestURL = requests.get('https://data.cityofnewyork.us/resource/8h9b-rp9u.json?$query=SELECT%20PERP_RACE%20WHERE%20(ARREST_PRECINCT=26%20OR%20ARREST_PRECINCT=30)%20AND%20ARREST_DATE>=%27'+date1[i]+'T00:00:00.000%27%20AND%20ARREST_DATE<%27'+date2[i]+'T00:00:00.000%27%20LIMIT%2010000000') # (your url)
    data = arrestURL.json()
    with open((r'Arrests/Martin2012/cd9/'+names[i]), 'w') as f:
        json.dump(data, f)
for i in range(len(date1)):    
    arrestURL = requests.get('https://data.cityofnewyork.us/resource/8h9b-rp9u.json?$query=SELECT%20PERP_RACE%20WHERE%20(ARREST_BORO="M")%20AND%20ARREST_DATE>=%27'+date1[i]+'T00:00:00.000%27%20AND%20ARREST_DATE<%27'+date2[i]+'T00:00:00.000%27%20LIMIT%2010000000') # (your url)
    data = arrestURL.json()
    with open((r'Arrests/Martin2012/manhattan/'+names[i]), 'w') as f:
        json.dump(data, f)

# %%
#Zimmerman2013Arrests
date1=['2013-06-16','2013-06-23','2013-06-30','2013-07-07','2013-07-14','2013-07-21','2013-07-28','2013-08-04']
date2=['2013-06-23','2013-06-30','2013-07-07','2013-07-14','2013-07-21','2013-07-28','2013-08-04','2013-08-11']
names=['week1.json','week2.json','week3.json','week4.json','week5.json','week6.json','week7.json','week8.json']
for i in range(len(date1)):    
    arrestURL = requests.get('https://data.cityofnewyork.us/resource/8h9b-rp9u.json?$query=SELECT%20PERP_RACE%20WHERE%20(ARREST_PRECINCT=26%20OR%20ARREST_PRECINCT=30)%20AND%20ARREST_DATE>=%27'+date1[i]+'T00:00:00.000%27%20AND%20ARREST_DATE<%27'+date2[i]+'T00:00:00.000%27%20LIMIT%2010000000') # (your url)
    data = arrestURL.json()
    with open((r'Arrests/Zimmerman2013/cd9/'+names[i]), 'w') as f:
        json.dump(data, f)
for i in range(len(date1)):    
    arrestURL = requests.get('https://data.cityofnewyork.us/resource/8h9b-rp9u.json?$query=SELECT%20PERP_RACE%20WHERE%20(ARREST_BORO="M")%20AND%20ARREST_DATE>=%27'+date1[i]+'T00:00:00.000%27%20AND%20ARREST_DATE<%27'+date2[i]+'T00:00:00.000%27%20LIMIT%2010000000') # (your url)
    data = arrestURL.json()
    with open((r'Arrests/Zimmerman2013/manhattan/'+names[i]), 'w') as f:
        json.dump(data, f)

# %%
#Ferguson2014Arrests
date1=['2014-10-28','2014-11-04','2014-11-11','2014-11-18','2014-11-25','2014-12-02','2014-12-09','2014-12-16']
date2=['2014-11-04','2014-11-11','2014-11-18','2014-11-25','2014-12-02','2014-12-09','2014-12-16','2014-12-23',]
names=['week1.json','week2.json','week3.json','week4.json','week5.json','week6.json','week7.json','week8.json']
for i in range(len(date1)):    
    arrestURL = requests.get('https://data.cityofnewyork.us/resource/8h9b-rp9u.json?$query=SELECT%20PERP_RACE%20WHERE%20(ARREST_PRECINCT=26%20OR%20ARREST_PRECINCT=30)%20AND%20ARREST_DATE>=%27'+date1[i]+'T00:00:00.000%27%20AND%20ARREST_DATE<%27'+date2[i]+'T00:00:00.000%27%20LIMIT%2010000000') # (your url)
    data = arrestURL.json()
    with open((r'Arrests/Ferguson2014/cd9/'+names[i]), 'w') as f:
        json.dump(data, f)
for i in range(len(date1)):    
    arrestURL = requests.get('https://data.cityofnewyork.us/resource/8h9b-rp9u.json?$query=SELECT%20PERP_RACE%20WHERE%20(ARREST_BORO="M")%20AND%20ARREST_DATE>=%27'+date1[i]+'T00:00:00.000%27%20AND%20ARREST_DATE<%27'+date2[i]+'T00:00:00.000%27%20LIMIT%2010000000') # (your url)
    data = arrestURL.json()
    with open((r'Arrests/Ferguson2014/manhattan/'+names[i]), 'w') as f:
        json.dump(data, f)

# %%
#Gray2015Arrests
date1=['2015-03-23','2015-03-30','2015-04-06','2015-04-13','2015-04-20','2015-04-27','2015-05-04','2015-05-11']
date2=['2015-03-30','2015-04-06','2015-04-13','2015-04-20','2015-04-27','2015-05-04','2015-05-11','2015-05-18']
names=['week1.json','week2.json','week3.json','week4.json','week5.json','week6.json','week7.json','week8.json']
for i in range(len(date1)):    
    arrestURL = requests.get('https://data.cityofnewyork.us/resource/8h9b-rp9u.json?$query=SELECT%20PERP_RACE%20WHERE%20(ARREST_PRECINCT=26%20OR%20ARREST_PRECINCT=30)%20AND%20ARREST_DATE>=%27'+date1[i]+'T00:00:00.000%27%20AND%20ARREST_DATE<%27'+date2[i]+'T00:00:00.000%27%20LIMIT%2010000000') # (your url)
    data = arrestURL.json()
    with open((r'Arrests/Gray2015/cd9/'+names[i]), 'w') as f:
        json.dump(data, f)
for i in range(len(date1)):    
    arrestURL = requests.get('https://data.cityofnewyork.us/resource/8h9b-rp9u.json?$query=SELECT%20PERP_RACE%20WHERE%20(ARREST_BORO="M")%20AND%20ARREST_DATE>=%27'+date1[i]+'T00:00:00.000%27%20AND%20ARREST_DATE<%27'+date2[i]+'T00:00:00.000%27%20LIMIT%2010000000') # (your url)
    data = arrestURL.json()
    with open((r'Arrests/Gray2015/manhattan/'+names[i]), 'w') as f:
        json.dump(data, f)

# %%
#Floyd2020Arrests
date1=['2020-04-27','2020-05-05','2020-05-12','2020-05-19','2020-05-26','2020-06-02','2020-06-09','2020-06-16']
date2=['2020-05-05','2020-05-12','2020-05-19','2020-05-26','2020-06-02','2020-06-09','2020-06-16','2020-06-23',]
names=['week1.json','week2.json','week3.json','week4.json','week5.json','week6.json','week7.json','week8.json']
for i in range(len(date1)):    
    arrestURL = requests.get('https://data.cityofnewyork.us/resource/uip8-fykc.json?$query=SELECT%20PERP_RACE%20WHERE%20(ARREST_PRECINCT=26%20OR%20ARREST_PRECINCT=30)%20AND%20ARREST_DATE>=%27'+date1[i]+'T00:00:00.000%27%20AND%20ARREST_DATE<%27'+date2[i]+'T00:00:00.000%27%20LIMIT%2010000000') # (your url)
    data = arrestURL.json()
    with open((r'Arrests/Floyd2020/cd9/'+names[i]), 'w') as f:
        json.dump(data, f)
for i in range(len(date1)):    
    arrestURL = requests.get('https://data.cityofnewyork.us/resource/uip8-fykc.json?$query=SELECT%20PERP_RACE%20WHERE%20(ARREST_BORO="M")%20AND%20ARREST_DATE>=%27'+date1[i]+'T00:00:00.000%27%20AND%20ARREST_DATE<%27'+date2[i]+'T00:00:00.000%27%20LIMIT%2010000000') # (your url)
    data = arrestURL.json()
    with open((r'Arrests/Floyd2020/manhattan/'+names[i]), 'w') as f:
        json.dump(data, f)

# %%
#Martin2012Complaints
date1=['2012-02-13','2012-02-20','2012-02-27','2012-03-05','2012-03-12','2012-03-19','2012-03-26','2012-04-02']
date2=['2012-02-20','2012-02-27','2012-03-05','2012-03-12','2012-03-19','2012-03-26','2012-04-02','2012-04-09']
names=['week1.json','week2.json','week3.json','week4.json','week5.json','week6.json','week7.json','week8.json']
for i in range(len(date1)):    
    complaintURL = requests.get('https://data.cityofnewyork.us/resource/qgea-i56i.json?$query=SELECT%20SUSP_RACE%20WHERE%20(ADDR_PCT_CD=26%20OR%20ADDR_PCT_CD=30)%20AND%20RPT_DT>=%27'+date1[i]+'T00:00:00.000%27%20AND%20RPT_DT<%27'+date2[i]+'T00:00:00.000%27%20LIMIT%2010000000') # (your url)
    data = complaintURL.json()
    with open((r'Complaints/Martin2012/cd9/'+names[i]), 'w') as f:
        json.dump(data, f)
for i in range(len(date1)):    
    complaintURL = requests.get('https://data.cityofnewyork.us/resource/qgea-i56i.json?$query=SELECT%20SUSP_RACE%20WHERE%20(BORO_NM="MANHATTAN")%20AND%20RPT_DT>=%27'+date1[i]+'T00:00:00.000%27%20AND%20RPT_DT<%27'+date2[i]+'T00:00:00.000%27%20LIMIT%2010000000') # (your url)
    data = complaintURL.json()
    with open((r'Complaints/Martin2012/manhattan/'+names[i]), 'w') as f:
        json.dump(data, f)

# %%
#Zimmerman2013Complaints
date1=['2013-06-16','2013-06-23','2013-06-30','2013-07-07','2013-07-14','2013-07-21','2013-07-28','2013-08-04']
date2=['2013-06-23','2013-06-30','2013-07-07','2013-07-14','2013-07-21','2013-07-28','2013-08-04','2013-08-11']
names=['week1.json','week2.json','week3.json','week4.json','week5.json','week6.json','week7.json','week8.json']
for i in range(len(date1)):    
    complaintURL = requests.get('https://data.cityofnewyork.us/resource/qgea-i56i.json?$query=SELECT%20SUSP_RACE%20WHERE%20(ADDR_PCT_CD=26%20OR%20ADDR_PCT_CD=30)%20AND%20RPT_DT>=%27'+date1[i]+'T00:00:00.000%27%20AND%20RPT_DT<%27'+date2[i]+'T00:00:00.000%27%20LIMIT%2010000000') # (your url)
    data = complaintURL.json()
    with open((r'Complaints/Zimmerman2013/cd9/'+names[i]), 'w') as f:
        json.dump(data, f)
for i in range(len(date1)):    
    complaintURL = requests.get('https://data.cityofnewyork.us/resource/qgea-i56i.json?$query=SELECT%20SUSP_RACE%20WHERE%20(BORO_NM="MANHATTAN")%20AND%20RPT_DT>=%27'+date1[i]+'T00:00:00.000%27%20AND%20RPT_DT<%27'+date2[i]+'T00:00:00.000%27%20LIMIT%2010000000') # (your url)
    data = complaintURL.json()
    with open((r'Complaints/Zimmerman2013/manhattan/'+names[i]), 'w') as f:
        json.dump(data, f)

# %%
#Ferguson2014Complaints
date1=['2014-10-28','2014-11-04','2014-11-11','2014-11-18','2014-11-25','2014-12-02','2014-12-09','2014-12-16']
date2=['2014-11-04','2014-11-11','2014-11-18','2014-11-25','2014-12-02','2014-12-09','2014-12-16','2014-12-23',]
names=['week1.json','week2.json','week3.json','week4.json','week5.json','week6.json','week7.json','week8.json']
for i in range(len(date1)):    
    complaintURL = requests.get('https://data.cityofnewyork.us/resource/qgea-i56i.json?$query=SELECT%20SUSP_RACE%20WHERE%20(ADDR_PCT_CD=26%20OR%20ADDR_PCT_CD=30)%20AND%20RPT_DT>=%27'+date1[i]+'T00:00:00.000%27%20AND%20RPT_DT<%27'+date2[i]+'T00:00:00.000%27%20LIMIT%2010000000') # (your url)
    data = complaintURL.json()
    with open((r'Complaints/Ferguson2014/cd9/'+names[i]), 'w') as f:
        json.dump(data, f)
for i in range(len(date1)):    
    complaintURL = requests.get('https://data.cityofnewyork.us/resource/qgea-i56i.json?$query=SELECT%20SUSP_RACE%20WHERE%20(BORO_NM="MANHATTAN")%20AND%20RPT_DT>=%27'+date1[i]+'T00:00:00.000%27%20AND%20RPT_DT<%27'+date2[i]+'T00:00:00.000%27%20LIMIT%2010000000') # (your url)
    data = complaintURL.json()
    with open((r'Complaints/Ferguson2014/manhattan/'+names[i]), 'w') as f:
        json.dump(data, f)

# %%
#Gray2015Complaints
date1=['2015-03-23','2015-03-30','2015-04-06','2015-04-13','2015-04-20','2015-04-27','2015-05-04','2015-05-11']
date2=['2015-03-30','2015-04-06','2015-04-13','2015-04-20','2015-04-27','2015-05-04','2015-05-11','2015-05-18']
names=['week1.json','week2.json','week3.json','week4.json','week5.json','week6.json','week7.json','week8.json']
for i in range(len(date1)):    
    complaintURL = requests.get('https://data.cityofnewyork.us/resource/qgea-i56i.json?$query=SELECT%20SUSP_RACE%20WHERE%20(ADDR_PCT_CD=26%20OR%20ADDR_PCT_CD=30)%20AND%20RPT_DT>=%27'+date1[i]+'T00:00:00.000%27%20AND%20RPT_DT<%27'+date2[i]+'T00:00:00.000%27%20LIMIT%2010000000') # (your url)
    data = complaintURL.json()
    with open((r'Complaints/Gray2015/cd9/'+names[i]), 'w') as f:
        json.dump(data, f)
for i in range(len(date1)):    
    complaintURL = requests.get('https://data.cityofnewyork.us/resource/qgea-i56i.json?$query=SELECT%20SUSP_RACE%20WHERE%20(BORO_NM="MANHATTAN")%20AND%20RPT_DT>=%27'+date1[i]+'T00:00:00.000%27%20AND%20RPT_DT<%27'+date2[i]+'T00:00:00.000%27%20LIMIT%2010000000') # (your url)
    data = complaintURL.json()
    with open((r'Complaints/Gray2015/manhattan/'+names[i]), 'w') as f:
        json.dump(data, f)

# %%
#Floyd2020Complaints
date1=['2020-04-27','2020-05-05','2020-05-12','2020-05-19','2020-05-26','2020-06-02','2020-06-09','2020-06-16']
date2=['2020-05-05','2020-05-12','2020-05-19','2020-05-26','2020-06-02','2020-06-09','2020-06-16','2020-06-23',]
names=['week1.json','week2.json','week3.json','week4.json','week5.json','week6.json','week7.json','week8.json']
for i in range(len(date1)):    
    complaintURL = requests.get('https://data.cityofnewyork.us/resource/5uac-w243.json?$query=SELECT%20SUSP_RACE%20WHERE%20(ADDR_PCT_CD=26%20OR%20ADDR_PCT_CD=30)%20AND%20RPT_DT>=%27'+date1[i]+'T00:00:00.000%27%20AND%20RPT_DT<%27'+date2[i]+'T00:00:00.000%27%20LIMIT%2010000000') # (your url)
    data = complaintURL.json()
    with open((r'Complaints/Floyd2020/cd9/'+names[i]), 'w') as f:
        json.dump(data, f)
for i in range(len(date1)):    
    complaintURL = requests.get('https://data.cityofnewyork.us/resource/5uac-w243.json?$query=SELECT%20SUSP_RACE%20WHERE%20(BORO_NM="MANHATTAN")%20AND%20RPT_DT>=%27'+date1[i]+'T00:00:00.000%27%20AND%20RPT_DT<%27'+date2[i]+'T00:00:00.000%27%20LIMIT%2010000000') # (your url) # (your url)
    data = complaintURL.json()
    with open((r'Complaints/Floyd2020/manhattan/'+names[i]), 'w') as f:
        json.dump(data, f)

# %%
#2010-2019
years=['2010','2011','2012','2013','2014','2015','2016','2017','2018','2019','2020']
for i in range(len(years)-1):    
    complaintURL = requests.get('https://data.cityofnewyork.us/resource/qgea-i56i.json?$query=SELECT%20SUSP_RACE%20WHERE%20(ADDR_PCT_CD=26%20OR%20ADDR_PCT_CD=30)%20AND%20RPT_DT>=%27'+years[i]+'-01-01T00:00:00.000%27%20AND%20RPT_DT<%27'+years[i+1]+'-01-01T00:00:00.000%27%20LIMIT%2010000000') # (your url)
    data = complaintURL.json()
    with open((r'Complaints/Yearly/cd9/'+years[i]+'.json'), 'w') as f:
        json.dump(data, f)
for i in range(len(years)-1):    
    complaintURL = requests.get('https://data.cityofnewyork.us/resource/8h9b-rp9u.json?$query=SELECT%20PERP_RACE%20WHERE%20(ARREST_PRECINCT=26%20OR%20ARREST_PRECINCT=30)%20AND%20ARREST_DATE>=%27'+years[i]+'-01-01T00:00:00.000%27%20AND%20ARREST_DATE<%27'+years[i+1]+'-01-01T00:00:00.000%27%20LIMIT%2010000000') # (your url)
    data = complaintURL.json()
    with open((r'Arrests/Yearly/cd9/'+years[i]+'.json'), 'w') as f:
        json.dump(data, f)
for i in range(len(years)-1):    
    complaintURL = requests.get('https://data.cityofnewyork.us/resource/qgea-i56i.json?$query=SELECT%20SUSP_RACE%20WHERE%20(ADDR_PCT_CD=49)%20AND%20RPT_DT>=%27'+years[i]+'-01-01T00:00:00.000%27%20AND%20RPT_DT<%27'+years[i+1]+'-01-01T00:00:00.000%27%20LIMIT%2010000000') # (your url)
    data = complaintURL.json()
    with open((r'Complaints/Yearly/cd11/'+years[i]+'.json'), 'w') as f:
        json.dump(data, f)
for i in range(len(years)-1):    
    complaintURL = requests.get('https://data.cityofnewyork.us/resource/8h9b-rp9u.json?$query=SELECT%20PERP_RACE%20WHERE%20(ARREST_PRECINCT=49)%20AND%20ARREST_DATE>=%27'+years[i]+'-01-01T00:00:00.000%27%20AND%20ARREST_DATE<%27'+years[i+1]+'-01-01T00:00:00.000%27%20LIMIT%2010000000') # (your url)
    data = complaintURL.json()
    with open((r'Arrests/Yearly/cd11/'+years[i]+'.json'), 'w') as f:
        json.dump(data, f)
for i in range(len(years)-1):    
    complaintURL = requests.get('https://data.cityofnewyork.us/resource/qgea-i56i.json?$query=SELECT%20SUSP_RACE%20WHERE%20(BORO_NM="MANHATTAN")%20AND%20RPT_DT>=%27'+years[i]+'-01-01T00:00:00.000%27%20AND%20RPT_DT<%27'+years[i+1]+'-01-01T00:00:00.000%27%20LIMIT%2010000000') # (your url)
    data = complaintURL.json()
    with open((r'Complaints/Yearly/manhattan/'+years[i]+'.json'), 'w') as f:
        json.dump(data, f)
for i in range(len(years)-1):    
    complaintURL = requests.get('https://data.cityofnewyork.us/resource/8h9b-rp9u.json?$query=SELECT%20PERP_RACE%20WHERE%20(ARREST_BORO="M")%20AND%20ARREST_DATE>=%27'+years[i]+'-01-01T00:00:00.000%27%20AND%20ARREST_DATE<%27'+years[i+1]+'-01-01T00:00:00.000%27%20LIMIT%2010000000') # (your url)
    data = complaintURL.json()
    with open((r'Arrests/Yearly/manhattan/'+years[i]+'.json'), 'w') as f:
        json.dump(data, f)

        
#2020 June 30th
complaintURL = requests.get('https://data.cityofnewyork.us/resource/5uac-w243.json?$query=SELECT%20SUSP_RACE%20WHERE%20(ADDR_PCT_CD=26%20OR%20ADDR_PCT_CD=30)%20AND%20RPT_DT>=%272020-01-01T00:00:00.000%27%20AND%20RPT_DT<%272020-07-01T00:00:00.000%27%20LIMIT%2010000000') # (your url)
data = complaintURL.json()
with open((r'Complaints/Yearly/cd9/2020.json'), 'w') as f:
    json.dump(data, f)
complaintURL = requests.get('https://data.cityofnewyork.us/resource/uip8-fykc.json?$query=SELECT%20PERP_RACE%20WHERE%20(ARREST_PRECINCT=26%20OR%20ARREST_PRECINCT=30)%20AND%20ARREST_DATE>=%272020-01-01T00:00:00.000%27%20AND%20ARREST_DATE<%272020-07-01T00:00:00.000%27%20LIMIT%2010000000') # (your url)
data = complaintURL.json()
with open((r'Arrests/Yearly/cd9/2020.json'), 'w') as f:
    json.dump(data, f)
complaintURL = requests.get('https://data.cityofnewyork.us/resource/5uac-w243.json?$query=SELECT%20SUSP_RACE%20WHERE%20(ADDR_PCT_CD=49)%20AND%20RPT_DT>=%272020-01-01T00:00:00.000%27%20AND%20RPT_DT<%272020-07-01T00:00:00.000%27%20LIMIT%2010000000') # (your url)
data = complaintURL.json()
with open((r'Complaints/Yearly/cd11/2020.json'), 'w') as f:
    json.dump(data, f)
complaintURL = requests.get('https://data.cityofnewyork.us/resource/uip8-fykc.json?$query=SELECT%20PERP_RACE%20WHERE%20(ARREST_PRECINCT=49)%20AND%20ARREST_DATE>=%272020-01-01T00:00:00.000%27%20AND%20ARREST_DATE<%272020-07-01T00:00:00.000%27%20LIMIT%2010000000') # (your url)
data = complaintURL.json()
with open((r'Arrests/Yearly/cd11/2020.json'), 'w') as f:
    json.dump(data, f)
complaintURL = requests.get('https://data.cityofnewyork.us/resource/5uac-w243.json?$query=SELECT%20SUSP_RACE%20WHERE%20(BORO_NM="MANHATTAN")%20AND%20RPT_DT>=%272020-01-01T00:00:00.000%27%20AND%20RPT_DT<%272020-07-01T00:00:00.000%27%20LIMIT%2010000000') # (your url)
data = complaintURL.json()
with open((r'Complaints/Yearly/manhattan/2020.json'), 'w') as f:
    json.dump(data, f)
complaintURL = requests.get('https://data.cityofnewyork.us/resource/uip8-fykc.json?$query=SELECT%20PERP_RACE%20WHERE%20(ARREST_BORO="M")%20AND%20ARREST_DATE>=%272020-01-01T00:00:00.000%27%20AND%20ARREST_DATE<%272020-07-01T00:00:00.000%27%20LIMIT%2010000000') # (your url)
data = complaintURL.json()
with open((r'Arrests/Yearly/manhattan/2020.json'), 'w') as f:
    json.dump(data, f)
